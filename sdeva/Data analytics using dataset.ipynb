# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
a=pd.read_csv("C:/Users/ADMIN/Downloads/Admission_Predict_Ver1.1 (1).csv")

# %%
a
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
a.shape
# Out:
# (500, 9)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
b=a.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','SOP','LOR','Research'],axis=1)

# %%
b
# Out:
#      CGPA  Chance of Admit
# 0    9.65              0.92
# 1    8.87              0.76
# 2    8.00              0.72
# 3    8.67              0.80
# 4    8.21              0.65
# ..    ...               ...
# 495  9.02              0.87
# 496  9.87              0.96
# 497  9.56              0.93
# 498  8.43              0.73
# 499  9.04              0.84
#
# [500 rows x 2 columns]

# %%
x=b.iloc[:,0].values.reshape(-1,1)

# %%
x
# Out:
# array([[9.65],
#        [8.87],
#        [8.  ],
#        [8.67],
#        [8.21],
#        [9.34],
#        [8.2 ],
#        [7.9 ],
#        [8.  ],
#        [8.6 ],
#        [8.4 ],
#        [9.  ],
#        [9.1 ],
#        [8.  ],
#        [8.2 ],
#        [8.3 ],
#        [8.7 ],
#        [8.  ],
#        [8.8 ],
#        [8.5 ],
#        [7.9 ],
#        [8.4 ],
#        [9.5 ],
#        [9.7 ],
#        [9.8 ],
#        [9.6 ],
#        [8.8 ],
#        [7.5 ],
#        [7.2 ],
#        [7.3 ],
#        [8.1 ],
#        [8.3 ],
#        [9.4 ],
#        [9.6 ],
#        [9.8 ],
#        [9.2 ],
#        [8.4 ],
#        [7.8 ],
#        [7.5 ],
#        [7.7 ],
#        [8.  ],
#        [8.2 ],
#        [8.5 ],
#        [9.1 ],
#        [9.4 ],
#        [9.1 ],
#        [9.3 ],
#        [9.7 ],
#        [8.85],
#        [8.4 ],
#        [8.3 ],
#        [7.9 ],
#        [8.  ],
#        [8.1 ],
#        [8.  ],
#        [7.7 ],
#        [7.4 ],
#        [7.6 ],
# ...

# %%
y=b.iloc[:,1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('Linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
x_train.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
y_predict
# Out:
# array([[0.58421497],
#        [0.83706099],
#        [0.79070589],
#        [0.82863279],
#        [0.62846302],
#        [0.66428287],
#        [0.57157266],
#        [0.70642388],
#        [0.58000087],
#        [0.75910013],
#        [0.63267712],
#        [0.72117323],
#        [0.65164057],
#        [0.81177639],
#        [0.82652574],
#        [0.57789382],
#        [0.78649179],
#        [0.62635597],
#        [0.78859884],
#        [0.55893036],
#        [0.52732461],
#        [0.67271107],
#        [0.53364576],
#        [0.8918443 ],
#        [0.83284689],
#        [0.71485208],
#        [0.68535338],
#        [0.48729066],
#        [0.60107137],
#        [0.61582072],
#        [0.75699308],
#        [0.44936375],
#        [0.70010273],
#        [0.80756229],
#        [0.52732461],
#        [0.53575281],
#        [0.84970329],
#        [0.86445264],
#        [0.63689122],
#        [0.67903223],
#        [0.65796172],
#        [0.87498789],
#        [0.86023854],
# ...

# %%
c=pd.DataFrame(x_test,columns=['CGPA'])

# %%
c
# Out:
#      CGPA
# 0    7.92
# 1    9.12
# 2    8.90
# 3    9.08
# 4    8.13
# ..    ...
# 245  8.76
# 246  7.67
# 247  8.27
# 248  8.78
# 249  9.60
#
# [250 rows x 1 columns]

# %%
c['CHA']=y_test

# %%
c['PRDDATA']=y_predict

# %%
x_test
# Out:
# array([[7.92],
#        [9.12],
#        [8.9 ],
#        [9.08],
#        [8.13],
#        [8.3 ],
#        [7.86],
#        [8.5 ],
#        [7.9 ],
#        [8.75],
#        [8.15],
#        [8.57],
#        [8.24],
#        [9.  ],
#        [9.07],
#        [7.89],
#        [8.88],
#        [8.12],
#        [8.89],
#        [7.8 ],
#        [7.65],
#        [8.34],
#        [7.68],
#        [9.38],
#        [9.1 ],
#        [8.54],
#        [8.4 ],
#        [7.46],
#        [8.  ],
#        [8.07],
#        [8.74],
#        [7.28],
#        [8.47],
#        [8.98],
#        [7.65],
#        [7.69],
#        [9.18],
#        [9.25],
#        [8.17],
#        [8.37],
#        [8.27],
#        [9.3 ],
#        [9.23],
#        [8.56],
#        [8.72],
#        [8.87],
#        [9.78],
#        [9.14],
#        [8.03],
#        [8.25],
#        [8.36],
#        [8.04],
#        [8.13],
#        [8.96],
#        [8.56],
#        [9.1 ],
#        [7.86],
#        [9.23],
# ...

# %%
d=a.drop(['Serial No.','GRE Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
d
# Out:
#      TOEFL Score  Chance of Admit
# 0            118              0.92
# 1            107              0.76
# 2            104              0.72
# 3            110              0.80
# 4            103              0.65
# ..           ...               ...
# 495          108              0.87
# 496          117              0.96
# 497          120              0.93
# 498          103              0.73
# 499          113              0.84
#
# [500 rows x 2 columns]

# %%
xx=d.iloc[0:400,0].values.reshape(-1,1)

# %%
xx
# Out:
# array([[118],
#        [107],
#        [104],
#        [110],
#        [103],
#        [115],
#        [109],
#        [101],
#        [102],
#        [108],
#        [106],
#        [111],
#        [112],
#        [109],
#        [104],
#        [105],
#        [107],
#        [106],
#        [110],
#        [102],
#        [107],
#        [114],
#        [116],
#        [119],
#        [119],
#        [120],
#        [109],
#        [ 98],
#        [ 93],
#        [ 99],
#        [ 97],
#        [103],
#        [118],
#        [114],
#        [112],
#        [110],
#        [106],
#        [105],
#        [105],
#        [108],
#        [110],
#        [105],
#        [107],
#        [117],
#        [113],
#        [110],
#        [114],
#        [119],
#        [110],
#        [111],
#        [ 98],
#        [100],
#        [116],
#        [112],
#        [110],
#        [103],
#        [102],
#        [ 99],
#        [ 99],
#        [104],
#        [100],
#        [101],
# ...

# %%
yy=d.iloc[0:400,1].values.reshape(-1,1)

# %%
yy
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
xx_train,xx_test,yy_train,yy_test=train_test_split(xx,yy,train_size=0.8,random_state=0)

# %%
xx_test.shape
# Out:
# (80, 1)

# %%
lr.fit(xx_train,yy_train)
# Out:
# LinearRegression()

# %%
yy_predict=lr.predict(xx_test)

# %%
yy_predict
# Out:
# array([[0.68086825],
#        [0.77467209],
#        [0.77467209],
#        [0.68086825],
#        [0.68086825],
#        [0.5870644 ],
#        [0.75591132],
#        [0.66210748],
#        [0.92475824],
#        [0.90599748],
#        [0.68086825],
#        [0.8309544 ],
#        [0.77467209],
#        [0.56830363],
#        [0.81219363],
#        [0.66210748],
#        [0.54954287],
#        [0.77467209],
#        [0.56830363],
#        [0.71838979],
#        [0.94351901],
#        [0.8309544 ],
#        [0.69962902],
#        [0.51202133],
#        [0.79343286],
#        [0.5870644 ],
#        [0.49326056],
#        [0.68086825],
#        [0.92475824],
#        [0.69962902],
#        [0.60582517],
#        [0.71838979],
#        [0.71838979],
#        [0.56830363],
#        [0.81219363],
#        [0.81219363],
#        [0.69962902],
#        [0.8309544 ],
#        [0.62458594],
#        [0.90599748],
#        [0.71838979],
#        [0.71838979],
#        [0.75591132],
# ...

# %%
e=pd.DataFrame(xx_test,columns=["TOEFL"])

# %%
e['CHA']=yy_test

# %%
e['PRDDATA']=yy_predict

# %%
e
# Out:
#     TOEFL   CHA   PRDDATA
# 0     105  0.71  0.680868
# 1     110  0.70  0.774672
# 2     110  0.79  0.774672
# 3     105  0.73  0.680868
# 4     105  0.72  0.680868
# ..    ...   ...       ...
# 75    104  0.61  0.662107
# 76    103  0.69  0.643347
# 77    106  0.62  0.699629
# 78    116  0.93  0.887237
# 79     96  0.43  0.512021
#
# [80 rows x 3 columns]
