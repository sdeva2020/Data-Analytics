# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
movies=['JL','BATMAN','IRONMAN','MASK','AVENGERS']
percentage=[10,20,30,40,50]

# %%
plt.scatter(movies,percentage)

# %%
plt.plot(movies,percentage,linestyle='-.')

# %%
plt.bar(movies,percentage)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(percentage,labels=movies)
# Out:
# ([<matplotlib.patches.Wedge at 0x2d9ce93ab30>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'JL'),
#   Text(0.7360436312779136, 0.817459340184711, 'BATMAN'),
#   Text(-0.33991877217145816, 1.046162142464278, 'IRONMAN'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'MASK'),
#   Text(0.5500001932481627, -0.9526278325909777, 'AVENGERS')])

# %%
import numpy as np

# %%
time=np.arange(0,10,0.05)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25, 6.3 , 6.35, 6.4 , 6.45, 6.5 , 6.55,
#        6.6 , 6.65, 6.7 , 6.75, 6.8 , 6.85, 6.9 , 6.95, 7.  , 7.05, 7.1 ,
# ...

# %%
amplitude=np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
plt.plot(time,amplitude)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sb

# %%
sb.set(style='darkgrid')

# %%
random=np.random.randn(100)

# %%
random
# Out:
# array([-8.92929106e-01,  1.41301121e+00,  8.11060939e-02, -8.28479003e-01,
#        -3.42886315e-02,  5.22477286e-01,  4.67324491e-01, -1.61106590e+00,
#         2.39936611e-01, -1.59392030e+00, -7.47321903e-01, -1.69243521e-01,
#        -2.03839445e-01, -1.23172339e+00, -1.92264596e-01, -1.72639357e+00,
#        -4.16676692e-01,  2.34051347e-01, -5.06855868e-01,  1.15977286e+00,
#        -5.94308994e-01,  9.87091346e-01,  1.99875448e+00,  2.36136411e-01,
#        -2.78463852e-02,  9.33898401e-03, -1.26782023e+00, -6.74856613e-01,
#        -1.97097049e+00, -9.13785885e-01,  6.10705144e-01,  1.69782711e+00,
#         3.22184145e-01,  6.34885102e-01, -7.69027256e-01,  4.43228988e-01,
#         9.43839963e-01, -5.63107257e-01, -1.89862880e+00,  6.07033115e-01,
#         1.20619071e+00,  1.19771589e+00, -8.90408431e-01,  1.14638053e-01,
#         6.45209409e-01, -8.61564944e-01,  2.05065718e+00,  3.32307573e-01,
# ...

# %%
sb.histplot(random)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
roseline=sb.load_dataset('titanic')

# %%
roseline
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
roseline.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
roseline.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
sd=roseline=sb.load_dataset('tips')

# %%
sd
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sd.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sd.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sb.relplot(x='total_bill',y='tip',data=sd,col="time",hue="day",style="day",kind="scatter")

# %%
sb.catplot(x='day',y='total_bill',kind='box',data=sd)

# %%
sb.regplot(x='total_bill',y='tip',data=sd)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>
